# %% [markdown]
# <a href="https://colab.research.google.com/github/phmouras/Python_Exercises/blob/main/Exercises_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
x=range(0,10)
y=[math.exp(-xi - 1) for xi in x]  # isto se chama "list comprehension"
print(x)
print(y)

import matplotlib.pyplot as plt
import numpy as np
plt.bar(x,y,color="red",align="edge",width=1)
x1 = np.linspace(0,10, 1000) # intervalo de 0 a 10, com 1000 divisões
y1=[math.exp(-xi) for xi in x1]
plt.plot(x1,y1)
plt.show()
# Out:
# range(0, 10)
# [0.36787944117144233, 0.1353352832366127, 0.049787068367863944, 0.01831563888873418, 0.006737946999085467, 0.0024787521766663585, 0.0009118819655545162, 0.00033546262790251185, 0.00012340980408667956, 4.5399929762484854e-05]

# %%
x_i = 0
x_f = 10
dx = 1
x = np.arange(x_i,x_f,dx)
S = 0
for xi in x:
    S = S+ math.exp(-xi - 1)*dx # *dx que é 1 nesse caso
    
print("Soma de 10 caixinhas= ",S)

# %%
x=range(0,10)
y=[math.exp(-xi)  for xi in x]  # isto se chama "list comprehension"
print(x)
print(y)

import matplotlib.pyplot as plt
import numpy as np
plt.bar(x,y,color="red",align="edge",width=1)
x1 = np.linspace(0,10, 1000) # intervalo de 0 a 10, com 1000 divisões
y1=[((math.exp(-xi) + math.exp(-xi - 1)) / 2 ) for xi in x1]
plt.plot(x1,y1)
plt.show()
# Out:
# range(0, 10)
# [1.0, 0.36787944117144233, 0.1353352832366127, 0.049787068367863944, 0.01831563888873418, 0.006737946999085467, 0.0024787521766663585, 0.0009118819655545162, 0.00033546262790251185, 0.00012340980408667956]

# %%
x=range(0,10)
y=[math.sinh(xi) for xi in x]  # isto se chama "list comprehension"
print(x)
print(y)

plt.bar(x,y,color="red",align="edge",width=1)
sh = [math.sinh(xi) for xi in x1]
plt.plot(x1,sh)
plt.show()
# Out:
# range(0, 10)
# [0.0, 1.1752011936438014, 3.626860407847019, 10.017874927409903, 27.28991719712775, 74.20321057778875, 201.71315737027922, 548.3161232732465, 1490.4788257895502, 4051.54190208279]
